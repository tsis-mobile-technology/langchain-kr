# %%
pip install -U langchain langchain-openai

# %%
LANGCHAIN_TRACING_V2=True
LANGCHAIN_ENDPOINT="https://api.smith.langchain.com"
LANGCHAIN_API_KEY="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"
LANGCHAIN_PROJECT="pr-sunny-ant-92"

# %%
from langchain_community.chat_models import ChatOllama
# from langchain_openai import ChatOpenAI
ollama=ChatOllama(
        model="EEVE-Korean-Instruct-10.8B:latest "
    )
# llm = ChatOpenAI()
ollama.invoke("Hello, world!")
# Out:
# AIMessage(content="Hello, [user]! I'm here to help you with any questions or concerns you may have. How can I assist you today?", response_metadata={'model': 'EEVE-Korean-Instruct-10.8B:latest ', 'created_at': '2024-06-29T15:10:51.8516126Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 55119836700, 'load_duration': 54138406500, 'prompt_eval_count': 51, 'prompt_eval_duration': 96529000, 'eval_count': 30, 'eval_duration': 876711000}, id='run-7bb7a84c-3ab6-4f32-9a9b-c85e92db6c3f-0')
